# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4]
y = [10,20,25,30]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y,color='lightblue',linewidth=3)
ax.scatter([2,4,6],[5,15,25],color='darkgreen',marker='^')
ax.set_xlim(1,6.5)
# Out:
# (1, 6.5)

# %%
x = np.linspace(0,10,100)
y = np.cos(x)
z = np.sin(x)

# %%
data = 2 * np.random.random((10,10))
data2 = 3 * np.random.random((10,10))

# %%
Y,X = np.mgrid[-3:3:100j,-3:3:100j]

# %%
U = -1 - X**2 + Y
V = 1 + X - Y**2

# %%
from matplotlib.cbook import get_sample_data

# %%
img = np.load(get_sample_data('axes_grid/bivariate_normal.npy'))

# %%
fig = plt.figure()
fig2 = plt.figure(figsize=plt.figaspect(2.0))

# %%
fig.add_axes()
ax1 = fig.add_subplot(221)
ax3 = fig.add_subplot(212)
fig

# %%
fig3,axes = plt.subplots(nrows=2,ncols=2)
fig4,axes2 = plt.subplots(ncols=3)

# %%
lines = ax1.plot(x,y)
ax3.scatter(x,y)
fig

# %%
axes[0,0].bar([1,2,3],[3,4,5])
fig3

# %%
axes[1,0].barh([0.5,1,2.5],[0,1,2])
fig3

# %%
axes[1,1].axhline(.45)
fig3

# %%
axes[0,1].axvline(.65)
fig3

# %%
fig = plt.figure()
fig.add_axes()
ax1 = fig.add_subplot(221)
ax3 = fig.add_subplot(212)
ax1.fill(x,y,color='blue')

# %%
ax3.fill_between(x,y,color='yellow')
fig

# %%
fig,ax = plt.subplots()

# %%
im = ax.imshow(img,cmap='gist_earth',interpolation='nearest',vmin=-2,vmax=2)
fig

# %%
plt.plot(x,x,x,x**2,x,x**3)
# Out:
# [<matplotlib.lines.Line2D at 0x1134f62e8>,
#  <matplotlib.lines.Line2D at 0x1134f64a8>,
#  <matplotlib.lines.Line2D at 0x1134f6e48>]

# %%
fig,ax = plt.subplots()
ax.plot(x,y,alpha=.4)

# %%
ax.plot(x,y,c='k')
fig

# %%
fig,ax = plt.subplots()
im = ax.imshow(img,cmap='seismic')
fig.colorbar(im,orientation='horizontal')

# %%
fig,ax = plt.subplots()
ax.scatter(x,y,marker='.')

# %%
fig,ax = plt.subplots()
ax.plot(x,y,marker='o')

# %%
plt.plot(x,y,linewidth=8.0)

# %%
plt.plot(x,y,ls='solid')

# %%
plt.plot(x,y,ls='--')

# %%
plt.plot(x,y,'--',x**2,y**2,'-.')
# Out:
# [<matplotlib.lines.Line2D at 0x1145da828>,
#  <matplotlib.lines.Line2D at 0x1145daa20>]

# %%
fig3,axes = plt.subplots(nrows=2,ncols=2)
axes[0,1].arrow(0,0,.5,.5)

# %%
axes[1,1].quiver(y,z)
fig3

# %%
axes[0,1].streamplot(X,Y,U,V)
fig3

# %%
fig = plt.figure()
fig.add_axes()
ax1 = fig.add_subplot(221)
ax3 = fig.add_subplot(212)
ax1.hist(y)
# Out:
# (array([ 26.,   8.,   7.,   6.,   6.,   6.,   6.,   7.,   8.,  20.]),
#  array([ -9.99947166e-01,  -7.99952450e-01,  -5.99957733e-01,
#          -3.99963016e-01,  -1.99968300e-01,   2.64169119e-05,
#           2.00021134e-01,   4.00015850e-01,   6.00010567e-01,
#           8.00005283e-01,   1.00000000e+00]),
#  <a list of 10 Patch objects>)

# %%
ax3.boxplot(y)
fig

# %%
fig = plt.figure()
fig.add_axes()
ax1 = fig.add_subplot(221)
ax3 = fig.add_subplot(212)
ax3.violinplot(z)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x114e0b080>],
#  'cbars': <matplotlib.collections.LineCollection at 0x114e14208>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x114e03f60>,
#  'cmins': <matplotlib.collections.LineCollection at 0x114e0bba8>}

# %%
fig4,axes2 = plt.subplots(ncols=3)
axes2[0].pcolor(data2)

# %%
axes2[1].pcolormesh(data)
fig4

# %%
CS = plt.contour(X,Y,U)

# %%
axes2[2].contourf(data)
fig4

# %%
x = [1,2,3,4]
y = [10,20,25,30]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y,color='lightblue',linewidth=3)
ax.scatter([2,4,6],[5,15,25],color='darkgreen',marker='^')
ax.set_xlim(1,6.5)
ax.text(1,-2.1,'Example Graph',style='italic')

# %%
ax.annotate('Sine',
            xy=(8,0),
            xycoords='data',
            xytext=(10.5,0),
            textcoords='data',
            arrowprops=dict(arrowstyle='->',connectionstyle='arc3'),)
ax.set_xlim(0,10)
ax.set_ylim(-10,20)
fig

# %%
plt.title(r'$sigma_i=15$',fontsize=20)

# %%
ax.margins(x =.0,y=.1)
ax.axis('equal')
ax.set(xlim=[0,10.5],ylim=[-15,30])
fig

# %%
ax.set(title='An Example Axes',ylabel='Y-Axis',xlabel='X-Axis')
fig
